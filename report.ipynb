# %%
# Custom tools
from setup import Instance
from analyzer import TrendAnalyzer
from data_processing import DataStorage, DataAnalysis, DataSource, WebScrape
from linear_regression import LinearRegression

# %%
# Access global config from the config class and setup an instance for the datastore
instance = Instance()

def main():
    print("---------------------------------------------------------------")
    ticker = input("Run analysis on ASX ticker:")

    # Load historical prices from the datastore
    table_name = ticker+'.AX'
    data = instance.datastore.get_table_data(table_name)
    analyzer = TrendAnalyzer(table_name, data)
    analyzer.fundamentals_chart()

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------
# Run analysis on ASX ticker:BHP
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 15
#      12     analyzer.fundamentals_chart()
#      14 if __name__ == '__main__':
# ---> 15     main()
#
# Cell In[2], line 12, in main()
#      10 data = instance.datastore.get_table_data(table_name)
#      11 analyzer = TrendAnalyzer(table_name, data)
# ---> 12 analyzer.fundamentals_chart()
#
# File ~/Documents/dev/canna/TA/analyzer.py:40, in TrendAnalyzer.fundamentals_chart(self)
#      38 # Get the date range for the last 90 days
#      39 last_90_days = datetime.now() - timedelta(days=90)
# ---> 40 filtered_data = self.data[self.data['Date'] >= last_90_days]
#      42 # Plot the stock price with moving averages and Bollinger Bands
#      43 ax1.plot(filtered_data['Date'], filtered_data['Close'], label='Closing Price')
#
# File ~/Documents/dev/canna/TA/venv/lib/python3.11/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~/Documents/dev/canna/TA/venv/lib/python3.11/site-packages/pandas/core/arraylike.py:60, in OpsMixin.__ge__(self, other)
#      58 @unpack_zerodim_and_defer("__ge__")
#      59 def __ge__(self, other):
# ---> 60     return self._cmp_method(other, operator.ge)
#
# File ~/Documents/dev/canna/TA/venv/lib/python3.11/site-packages/pandas/core/series.py:6096, in Series._cmp_method(self, other, op)
#    6093 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6095 with np.errstate(all="ignore"):
# -> 6096     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6098 return self._construct_result(res_values, name=res_name)
#
# File ~/Documents/dev/canna/TA/venv/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:293, in comparison_op(left, right, op)
#     290     return invalid_comparison(lvalues, rvalues, op)
#     292 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 293     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     295 else:
#     296     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/Documents/dev/canna/TA/venv/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:82, in comp_method_OBJECT_ARRAY(op, x, y)
#      80     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      81 else:
# ---> 82     result = libops.scalar_compare(x.ravel(), y, op)
#      83 return result.reshape(x.shape)
#
# File ~/Documents/dev/canna/TA/venv/lib/python3.11/site-packages/pandas/_libs/ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>=' not supported between instances of 'str' and 'datetime.datetime'
